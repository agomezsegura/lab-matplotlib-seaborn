# %% [markdown]
# # Lab | Matplotlib & Seaborn
#
# #### Import all the necessary libraries here:

# %%
# Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Challenge 1
#
# #### The data we will use in this challenge is:

# %%
x = np.arange(0,100)
y = x*2
z = x**2

# %% [markdown]
# #### Plot (x, y) and (x, z).
# There are 2 ways of doing this. Do in both ways.
#
# **Hint**: Check out the nrows, ncols and index arguments of subplots.
#
# Also, play around with the linewidth and style. Use the ones you're most happy with.

# %%
# Method 1
plt.plot(x,y)

# %%
plt.plot(x,z)

# %% [markdown]
# #### Use plt.subplots(nrows=1, ncols=2) to create the plot.

# %%
# Method 2
fig, ax = plt.subplots(1, 2)
ax[0].plot(x, y)
ax[1].plot(x,z)

# %% [markdown]
# #### Use your previous code but now, resize your plot.
# **Hint**: Add the figsize argument in plt.subplots().
#
# If you want, try to add a title to the plot or even axes labels. You can also play with the fontweight and fontsize of the titles and labels.

# %%
# your code here
fig, ax = plt.subplots(1, 2, figsize = (20,5))
fig.suptitle('Linear and quadratic', fontsize = 18, fontweight = 'bold')
ax[0].set_title('Linear')
ax[0].plot(x, y)
ax[1].set_title('Quadratic')
ax[1].plot(x,z)

# %% [markdown]
# #### Now you will have to plot both $y=x^2$ and $y=e^x$ in the same plot. Create two subplots and use a normal scale in the first one and a logarithmic scale in the second one.
# **Hint**: Use `set_xscale` and `set_yscale`.

# %%
y3 = math.e**x

# %%
fig2, ax2 = plt.subplots(1, 2, figsize = (20,5))
fig.suptitle('Quadratic and exponential', fontsize = 18, fontweight = 'bold')
ax2[0].set_title('Quadratic')
ax2[0].plot(x, z, label = 'y=x^2')
ax2[1].set_title('Exponential')
ax2[1].plot(x, y3, label = 'y=e^x')
ax2[1].set_xscale('log')
ax2[1].set_yscale('log')
ax2[0].legend()
ax2[1].legend()

# %% [markdown]
# #### As a bonus challenge, try to add a legend to the plot.

# %% [markdown]
# #your code here
# Done above.

# %% [markdown]
# ## Challenge 2
# #### Import the `Fitbit2` dataset and store it in a variable called `fitbit`. You can find the dataset in Ironhack's database:
# * db: `fitbit`
# * table: `fitbit2`

# %%
# your code here
fitbit = pd.read_csv('data/fitbit2.csv')

# %%
fitbit
# Out:
#            Date  Calorie burned  Steps  Distance  Floors  Minutes Sedentary  \
# 0    2015-05-08            1934    905      0.65       0              1.355
# 1    2015-05-09            3631  18925     14.11       4            611.000
# 2    2015-05-10            3204  14228     10.57       1            602.000
# 3    2015-05-11            2673   6756      5.02       8            749.000
# 4    2015-05-12            2495    502      3.73       1            876.000
# ..          ...             ...    ...       ...     ...                ...
# 362  2016-05-03            3796  18588     14.13      16            599.000
# 363  2016-05-04            3525  16382     12.39      16            684.000
# 364  2016-05-05            3649  21913     16.40      19            701.000
# 365  2016-05-06            3539  19023     14.79      15            575.000
# 366  2016-05-07             304   9526      7.08       2            564.000
#
# ...

# %% [markdown]
# #### From the Fitbit data, we want to visually understand:
#
# How the average number of steps change by month. Use the appropriate visualization to show the median steps by month. Is Fitbitter more active on weekend or workdays? All plots must be in the same jupyter notebook cell.
#
# **Hints**:
#
# * Use Months_encoded and Week_or Weekend columns.
# * Use matplolib.pyplot object oriented API.
# * Set your size figure to 12,4
# * Explore plt.sca
# * Explore plt.xticks
# * Save your figures in a folder called `figures` in your repo.

# %%
# MEDIAN STEPS BY MONTH_ENCODED
# your code here
month_fitbit = fitbit.groupby(['Months_encoded']).median()['Steps'].reset_index()
fig3, ax3 = plt.subplots(figsize = (12,4))
ax3.bar('Months_encoded', 'Steps', data = month_fitbit)
plt.sca(ax3)
plt.xticks(range(1,13),['January', 'February', 'March', 'April', 'May', 'June', 'July', 'August', 'September', 'October', 'November', 'December']);

# MEDIAN STEPS BY WORK_OR_WEEKEND
# your code here
wow_fitbit = fitbit.groupby(['Work_or_Weekend']).median()['Steps'].reset_index()
fig4, ax4 = plt.subplots(figsize = (4,10))
plt.sca(ax4)
plt.xticks(range(2), ['Work', 'Weekend'])
ax4.bar('Work_or_Weekend', 'Steps', data = wow_fitbit);

# %% [markdown]
# #### Write a loop to plot 3 scatter plots of the following features:
#
# * Minutes Lightly Active vs Steps
# * Minutes Very Active vs Steps
# * Minutes Sedentary vs Steps

# %%
columns = ['Minutes Lightly Active', 'Minutes Very Active', 'Minutes Sedentary']
fig5, ax5 = plt.subplots(1, 3, figsize = (20,8))

for i in range(len(columns)):
    ax5[i].scatter(columns[i], 'Steps', data = fitbit)
    ax5[i].set_title(columns[i]+' vs Steps')

# %% [markdown]
# ## Challenge 3
#
# #### Import the `titanic` dataset and store it in a variable called `titanic`. You can find the dataset in Ironhack's database:
# * db: `titanic`
# * table: `titanic`

# %%
# your code here
titanic = pd.read_csv('data/titanic.csv')

# %% [markdown]
# #### Explore the titanic dataset using Pandas dtypes.

# %%
titanic.dtypes
# Out:
# PassengerId      int64
# Survived       float64
# Pclass           int64
# Name            object
# Gender          object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# #### What are your numerical variables? What are your categorical variables?
# **Hint**: Use Pandas select_dtypes.

# %%
# NUMERICAL VARIABLES
# your code here
titanic.select_dtypes([int,float])
# Out:
#       Survived        Age      Fare
# 0          0.0  22.000000    7.2500
# 1          1.0  38.000000   71.2833
# 2          1.0  26.000000    7.9250
# 3          1.0  35.000000   53.1000
# 4          0.0  35.000000    8.0500
# ...        ...        ...       ...
# 1304       NaN  29.513190    8.0500
# 1305       NaN  39.000000  108.9000
# 1306       NaN  38.500000    7.2500
# 1307       NaN  29.513190    8.0500
# 1308       NaN  25.315435   22.3583
#
# [1309 rows x 3 columns]

# %%
# CATEGORICAL VARIABLES
# your code here
titanic.select_dtypes([object])
# Out:
#                                                    Name  Gender  \
# 0                               Braund, Mr. Owen Harris    male
# 1     Cumings, Mrs. John Bradley (Florence Briggs Th...  female
# 2                                Heikkinen, Miss. Laina  female
# 3          Futrelle, Mrs. Jacques Heath (Lily May Peel)  female
# 4                              Allen, Mr. William Henry    male
# ...                                                 ...     ...
# 1304                                 Spector, Mr. Woolf    male
# 1305                       Oliva y Ocana, Dona. Fermina  female
# 1306                       Saether, Mr. Simon Sivertsen    male
# 1307                                Ware, Mr. Frederick    male
# 1308                           Peter, Master. Michael J    male
#
#                   Ticket Cabin Embarked
# 0              A/5 21171    U0        S
# 1               PC 17599   C85        C
# 2       STON/O2. 3101282    U0        S
# ...

# %% [markdown]
# #### Set the plot style to classic and the figure size to (12,6).
# **Hint**: To set the style you can use matplotlib or seaborn functions. Do some research on the matter.

# %%
# your code here
plt.style.use('classic')
fig6, ax6 = plt.subplots(figsize = (12,6))

# %% [markdown]
# #### Use the right visulalization to show the distribution of column `Age`.

# %%
# your code here
fig6, ax6 = plt.subplots(figsize = (12,6))
ax6.hist('Age', data = titanic);

# %% [markdown]
# #### Use subplots and plot the distribution of the `Age`  with bins equal to 10, 20 and 50.

# %%
# your code here
bins_size = [10,20,50]
fig7, ax7 = plt.subplots(1, 3, figsize = (12,6))
for i in range(len(bins_size)):
    ax7[i].hist('Age', data = titanic, bins = bins_size[i]);

# %%
titanic_10 = titanic[titanic['Age']<=10]
titanic_20 = titanic[titanic['Age']>10]
titanic_20 = titanic_20[titanic_20['Age']<=20]
titanic_50 = titanic[titanic['Age']>20]
titanic_50 = titanic_50[titanic_50['Age']<=50]
datas = [titanic_10, titanic_20, titanic_50]
fig8, ax8 = plt.subplots(1, 3, figsize = (12,6))
for i in range(len(datas)):
    ax8[i].hist('Age', data = datas[i])

# %% [markdown]
# #### How does the bin size affect your plot?

# %% [markdown]
# Increasing bin size gives more precised distribution.

# %% [markdown]
# #### Use seaborn to show the distribution of column `Age`.

# %%
fig9, ax9 = plt.subplots(figsize = (12,8))

sns.distplot(titanic['Age'])

# %% [markdown]
# #### Use the right plot to visualize column `Gender`. There are 2 ways of doing it. Do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
# your code here
y = titanic['Gender'].value_counts().values
fig10, ax10 = plt.subplots(figsize = (12,8))
ax10.bar(titanic['Gender'].value_counts().index, titanic['Gender'].value_counts())
# Out:
# <BarContainer object of 2 artists>

# %%
titanic['Gender'].value_counts().values
# Out:
# array([843, 466], dtype=int64)

# %%
# Method 2 - seaborn
# your code here
fig11, ax11 = plt.subplots(figsize = (12,8))
sns.barplot(titanic['Gender'].value_counts().index, titanic['Gender'].value_counts(), ax = ax11)

# %% [markdown]
# #### Use the right plot to visualize the column `Pclass`.

# %%
pclass = titanic['Pclass'].value_counts().sort_values()
pclass_index = ["first", "second", "third"]
sns.barplot(x=pclass_index, y=pclass).set_title("Available passenger classes", fontsize=15)
plt.ylabel("passengers");

# %% [markdown]
# #### We would like to have in one single plot the summary statistics of the feature `Age`. What kind of plot would you use? Plot it.

# %%
sns.boxplot(x=titanic["Age"])
plt.title("Ages distribution of Titanic");

# %% [markdown]
# #### What does the last plot tell you about the feature `Age`?

# %%
"""
Boxplot can plot the summary statistics of the Age feature, showing that the mean is approximately 29. Ages are between 0 and 80,
where 75% of passeneger's ages are between 0-60 and 50% between 21-38.
"""
# Out:
# "\nBoxplot can plot the summary statistics of the Age feature, showing that the mean is approximately 29. Ages are between 0 and 80,\nwhere 75% of passeneger's ages are between 0-60 and 50% between 21-38.\n"

# %% [markdown]
# #### Now in addition to the summary statistics, we want to have in the same plot the distribution of `Age`. What kind of plot would you use? Plot it.

# %%
fig12, ax12 = plt.subplots(nrows=1, ncols=1, figsize =(5,10))

titanic.boxplot(column='Age')

for i in [1]:
    y = titanic["Age"]
    x = np.random.normal(i, 0.04, size=len(y))
    plt.plot(x, y, 'm.', alpha=0.1)

# %% [markdown]
# #### What additional information does the last plot provide about feature `Age`?

# %%
"""
your comments here
"""
# Out:
# '\nyour comments here\n'

# %% [markdown]
# #### We suspect that there is a linear relationship between `Fare` and `Age`. Use the right plot to show the relationship between these 2 features. There are 2 ways, please do it both ways.
# **Hint**: Use matplotlib and seaborn.

# %%
# Method 1 - matplotlib
fig13, ax13 = plt.subplots(figsize=(12,5))
ax13.scatter(x=titanic["Fare"], y=titanic["Age"], alpha=0.3, color="mediumorchid")
ax13.set_title("Linear relationship between fare and age of the passengers", fontsize="14")
plt.xlabel("Fare")
plt.ylabel("Age");

# %%
# Method 2 - seaborn
fig14, ax14 = plt.subplots(figsize=(12,5))
sns.scatterplot(x=titanic["Fare"], y=titanic["Age"], color="mediumorchid", alpha=0.4)
ax14.set_title("Linear relationship between fare and age of the passengers", fontsize="14");

# %% [markdown]
# #### Plot the correlation matrix using seaborn.

# %%
corr = titanic.corr()
fig15, ax15 = plt.subplots(figsize=(10,5))
ax15 = sns.heatmap(corr, vmax=1, center=0, square=True)
ax15.set_title("Correlation plot", fontsize=14);

# %% [markdown]
# #### What are the most correlated features?

# %%
"""
Pclass-Fare, negative correlation
"""
# Out:
# '\nPclass-Fare, negative correlation\n'

# %% [markdown]
# #### Use the most appropriate plot to display the summary statistics of `Age` depending on `Pclass`.

# %%
fig16, ax16 = plt.subplots(figsize=(5,5))
sns.boxplot(x=titanic["Pclass"], y=titanic["Age"], data=titanic);

# %% [markdown]
# #### Use seaborn to plot the distribution of `Age` based on the `Gender`.
# **Hint**: Use Facetgrid.

# %%
g = sns.FacetGrid(data=titanic, col="Gender")
g.map(plt.hist, "Age");
